# %% [markdown]
# Datos extraidos de: https://www.kaggle.com/datasets/adityadesai13/used-car-dataset-ford-and-mercedes/data

# %%
import os
import pandas as pd
import numpy as np

# Define the path to the directory
dir_path = 'archive'

# Get a list of all files in the directory
files = os.listdir(dir_path)

# Initialize an empty list to store the DataFrames
dfs = []
data = pd.DataFrame()

# Iterate over the list of files
for file in files:
    # Check if the file is a CSV file
    if file.endswith('.csv'):
        # Construct the full file path
        file_path = os.path.join(dir_path, file)
        # Load the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        # Append the DataFrame to the list
        dfs.append(df)
        df['brand'] = file.split('.')[0]
        data = pd.concat([data,df])
for dataset in dfs:

    print(f'\n')
    print(f'dataset: {dataset.columns}')
    print(f'\n')
# Out:
# dataset: Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize', 'brand'],
#       dtype='object')
#
#
#
#
# dataset: Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType',
#        'engineSize', 'brand'],
#       dtype='object')
#
#
#
#
# dataset: Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize', 'brand'],
#       dtype='object')
#
#
#
#
# dataset: Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType',
#        'tax(£)', 'mpg', 'engineSize', 'brand'],
#       dtype='object')
#
#
#
#
# dataset: Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize', 'brand'],
#       dtype='object')
#
#
#
#
# dataset: Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize', 'brand'],
#       dtype='object')
#
#
#
#
# ...

# %%
for dataset in dfs:
    print(f'\n')
    print(f'dataset: {dataset.info()}')
    print(f'\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6267 entries, 0 to 6266
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         6267 non-null   object
#  1   year          6267 non-null   int64
#  2   price         6267 non-null   int64
#  3   transmission  6267 non-null   object
#  4   mileage       6267 non-null   int64
#  5   fuelType      6267 non-null   object
#  6   tax           6267 non-null   int64
#  7   mpg           6267 non-null   float64
#  8   engineSize    6267 non-null   float64
#  9   brand         6267 non-null   object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 489.7+ KB
# dataset: None
#
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5454 entries, 0 to 5453
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         5454 non-null   object
# ...

# %%
#Analizing the empty values in each dataset
for dataset in dfs:
    print(f'\n')
    print(f'dataset: {dataset.isnull().sum()}')
    print(f'\n')
# Out:
# dataset: model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# brand           0
# dtype: int64
#
#
#
#
# dataset: model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# engineSize      0
# brand           0
# dtype: int64
#
#
#
#
# dataset: model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# brand           0
# dtype: int64
#
#
#
#
# dataset: model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax(£)          0
# mpg             0
# engineSize      0
# brand           0
# dtype: int64
#
#
#
#
# dataset: model           0
# year            0
# price           0
# transmission    0
# mileage         0
# ...

# %%
#Working only with the first 9 columns of the combined dataset
data = data.iloc[:, :10]
print(data)
# Out:
#                model    year  price transmission mileage fuelType    tax  \
# 0            Octavia  2017.0  10550       Manual   25250   Petrol  150.0
# 1             Citigo  2018.0   8200       Manual    1264   Petrol  145.0
# 2            Octavia  2019.0  15650    Automatic    6825   Diesel  145.0
# 3       Yeti Outdoor  2015.0  14000    Automatic   28431   Diesel  165.0
# 4             Superb  2019.0  18350       Manual   10912   Petrol  150.0
# ...              ...     ...    ...          ...     ...      ...    ...
# 13627          Tigra  2007.0   2499       Manual   48640   Petrol  165.0
# 13628         Vectra  2007.0   1795       Manual   75000   Petrol  240.0
# 13629         Vectra  2005.0   1495       Manual   74000   Petrol  235.0
# 13630         Vectra  2008.0   1695    Automatic  131000   Diesel  200.0
# 13631         Vectra  2005.0   1450       Manual  147000   Petrol  330.0
#
#         mpg  engineSize     brand
# 0      54.3         1.4     skoda
# ...

# %%
#Checking empty values in the combined dataset
print(f'\n')
print(f'data: {data.isnull().sum()}')
# Out:
# data: model             155
# year              247
# price             155
# transmission      155
# mileage          1073
# fuelType         9610
# tax             23823
# mpg             18963
# engineSize       9610
# brand               0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118150 entries, 0 to 13631
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   model         117995 non-null  object
#  1   year          117903 non-null  float64
#  2   price         117995 non-null  object
#  3   transmission  117995 non-null  object
#  4   mileage       117077 non-null  object
#  5   fuelType      108540 non-null  object
#  6   tax           94327 non-null   float64
#  7   mpg           99187 non-null   float64
#  8   engineSize    108540 non-null  float64
#  9   brand         118150 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 9.9+ MB

# %%
#Changing price column to float
data['price'] = data['price'].replace('[\£,]', '', regex=True).astype(float)
data['price'] = data['price'].replace('[\$,]', '', regex=True).astype(float)
data
# Out:
#                model    year    price transmission mileage fuelType    tax  \
# 0            Octavia  2017.0  10550.0       Manual   25250   Petrol  150.0
# 1             Citigo  2018.0   8200.0       Manual    1264   Petrol  145.0
# 2            Octavia  2019.0  15650.0    Automatic    6825   Diesel  145.0
# 3       Yeti Outdoor  2015.0  14000.0    Automatic   28431   Diesel  165.0
# 4             Superb  2019.0  18350.0       Manual   10912   Petrol  150.0
# ...              ...     ...      ...          ...     ...      ...    ...
# 13627          Tigra  2007.0   2499.0       Manual   48640   Petrol  165.0
# 13628         Vectra  2007.0   1795.0       Manual   75000   Petrol  240.0
# 13629         Vectra  2005.0   1495.0       Manual   74000   Petrol  235.0
# 13630         Vectra  2008.0   1695.0    Automatic  131000   Diesel  200.0
# 13631         Vectra  2005.0   1450.0       Manual  147000   Petrol  330.0
#
#         mpg  engineSize     brand
# ...

# %%
print(data['brand'].unique()) # la unica que presenta valores raros 
print(data['fuelType'].unique())
print(data['transmission'].unique())
# Out:
# ['skoda' 'focus' 'merc' 'hyundi' 'toyota' 'bmw' 'ford' 'unclean cclass'
#  'unclean focus' 'cclass' 'vw' 'audi' 'vauxhall']
# ['Petrol' 'Diesel' 'Hybrid' 'Other' 'Electric' nan]
# ['Manual' 'Automatic' 'Semi-Auto' 'Other' nan]

# %%
data['brand'] = data['brand'].replace('focus', 'ford', regex=True)
data['brand'] = data['brand'].replace('unclean focus', 'ford', regex=True)
data['brand'] = data['brand'].replace('unclean ford', 'ford', regex=True)
data['brand'] = data['brand'].replace('unclean cclass', 'cclass', regex=True)

# %%
data['brand'].value_counts()
# Out:
# brand
# ford        29023
# vw          15157
# vauxhall    13632
# merc        13119
# bmw         10781
# audi        10668
# cclass       7905
# toyota       6738
# skoda        6267
# hyundi       4860
# Name: count, dtype: int64

# %%
data['mileage']
# Out:
# 0         25250
# 1          1264
# 2          6825
# 3         28431
# 4         10912
#           ...
# 13627     48640
# 13628     75000
# 13629     74000
# 13630    131000
# 13631    147000
# Name: mileage, Length: 118150, dtype: object

# %%
import pandas as pd
import numpy as np



# Convertir la columna 'mileage' a tipo float
data['mileage'] = pd.to_numeric(data['mileage'], errors='coerce')
data['mileage']
# Out:
# 0         25250.0
# 1          1264.0
# 2          6825.0
# 3         28431.0
# 4         10912.0
#            ...
# 13627     48640.0
# 13628     75000.0
# 13629     74000.0
# 13630    131000.0
# 13631    147000.0
# Name: mileage, Length: 118150, dtype: float64

# %%
data = data.dropna(subset=['brand', 'transmission', 'fuelType'])
data.isnull().sum()
# Out:
# model               0
# year                0
# price               0
# transmission        0
# mileage             0
# fuelType            0
# tax             14213
# mpg              9353
# engineSize          0
# brand               0
# dtype: int64

# %%
#Libreria para hacer un reporte rapido
from ydata_profiling import ProfileReport

# %%
# Generate the Pandas Profiling report
profile = ProfileReport(data, title='Pandas Profiling Report', explorative=True, dark_mode=True, minimal=True, progress_bar=True)
profile.config.html.minify_html = True

# Save the report as an HTML file
profile.to_file("output.html")
# Out:
# /home/juan/.local/lib/python3.10/site-packages/ydata_profiling/utils/dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 850.08it/s]

# %%
len(data)
# Out:
# 108540

# %%
data = data.drop_duplicates(keep='first')
len(data)
# Out:
# 106259

# %%
# Para split el data
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(data, test_size=0.2, random_state=42, shuffle=True)
train, val = train_test_split(train, test_size=0.25, random_state=42, shuffle=True)#Tamaño de los conjuntos de datos
distribution = np.array([len(train), len(val), len(test)])

print(distribution)
print(distribution/ len(data))
# Out:
# [63755 21252 21252]
# [0.59999624 0.20000188 0.20000188]

# %%
train.head(5)
# Out:
#           model    year    price transmission  mileage fuelType    tax   mpg  \
# 693     C Class  2018.0  27980.0    Semi-Auto  12173.0   Diesel    NaN   NaN
# 8809    Mokka X  2019.0  14450.0       Manual   7641.0   Petrol  145.0  39.2
# 233     M Class  2013.0  15990.0    Automatic  51800.0   Diesel  200.0  44.8
# 9408         Q2  2017.0  17995.0       Manual  16829.0   Petrol  145.0  52.3
# 7931   3 Series  2017.0  19499.0    Automatic  24472.0   Diesel   30.0  62.8
#
#       engineSize     brand
# 693          2.0    cclass
# 8809         1.4  vauxhall
# 233          2.1      merc
# 9408         1.4      audi
# 7931         2.0       bmw

# %%
#pd.get_dummies(train[['brand','transmission', 'fuelType']]) #Dummies para las variables categoricas que considere pertinentes, sin embargo hay una mejor manera

# %%
from sklearn.preprocessing import OneHotEncoder #LabelEncoder para variables categóricas ordinales
maker_encoder = OneHotEncoder()

# %%
maker_encoder.fit(train[['brand', 'transmission', 'fuelType']]) # Esta es una mejor manera de tratar con estas variables categóricas, ya que no se le asigna un valor numérico a cada categoría, sino que se crea una columna por cada categoría y se le asigna un 1 si pertenece a esa categoría y un 0 si no
# Out:
# OneHotEncoder()

# %%
print(len(train['brand'].unique()) + len(train['transmission'].unique()) + len(train['fuelType'].unique()))
# Out:
# 19

# %%
mkr = maker_encoder.transform(train[['brand', 'transmission', 'fuelType']])
mkr.shape #coincide con el número de filas del conjunto de datos de entrenamiento
# Out:
# (63755, 19)

# %%
maker_encoder.categories_ #Using OneHotEncoder we avoid hiving weights to the different brands, transmission and fuelType
# Out:
# [array(['audi', 'bmw', 'cclass', 'ford', 'hyundi', 'merc', 'skoda',
#         'toyota', 'vauxhall', 'vw'], dtype=object),
#  array(['Automatic', 'Manual', 'Other', 'Semi-Auto'], dtype=object),
#  array(['Diesel', 'Electric', 'Hybrid', 'Other', 'Petrol'], dtype=object)]

# %% [markdown]
# # Feature scaling

# %%
 # Feature scaling
''' 
Recomendado cuando los datos tienen diferentes escalas, por ejemplo, si una columna tiene valores entre 0 y 1 y otra entre 0 y 1000.
El escalado de características es un paso importante en la preparación de datos para algoritmos de aprendizaje automático que se ven afectados por la escala de las características, como la regresión lineal, la regresión logística y las redes neuronales.
Recomendado cuando la distribución de las características es asimétrica o con valores atípicos.
Recomendado cuando se utilizan algoritmos que utilizan medidas de distancia, como k-vecinos más cercanos (KNN) o k-medias.

'''
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, MaxAbsScaler, Normalizer
scaler = MaxAbsScaler()
''' 
StandardScaler: Escala las características eliminando la media y escalando a la varianza unitaria.
RobustScaler: Escala las características utilizando estadísticas robustas para evitar que los valores atípicos afecten la escala.
MinMaxScaler: Escala las características en un rango dado, generalmente entre 0 y 1.
MaxAbsScaler: Escala las características en el rango [-1, 1] dividiendo por el valor máximo absoluto.
Normalizer: Escala las características a una norma unitaria.
'''
scaler.fit(train[['mileage']])
# Out:
# MaxAbsScaler()

# %%
scaled = scaler.transform(train[['mileage']])

# %%
scaled
# Out:
# array([[0.03768731],
#        [0.02365635],
#        [0.16037152],
#        ...,
#        [0.13931889],
#        [0.07740557],
#        [0.06814861]])

# %%
#Valores originales vs escalados
valuesTemp = pd.DataFrame({'original': train['mileage'].values, 'scaled': scaled.squeeze()})
valuesTemp
# Out:
#        original    scaled
# 0       12173.0  0.037687
# 1        7641.0  0.023656
# 2       51800.0  0.160372
# 3       16829.0  0.052102
# 4       24472.0  0.075765
# ...         ...       ...
# 63750   22861.0  0.070777
# 63751   14950.0  0.046285
# 63752   45000.0  0.139319
# 63753   25002.0  0.077406
# 63754   22012.0  0.068149
#
# [63755 rows x 2 columns]

# %%
valuesTemp.describe()
# Out:
#             original        scaled
# count   63755.000000  63755.000000
# mean    23141.601569      0.071646
# std     21037.381105      0.065131
# min         1.000000      0.000003
# 25%      7696.000000      0.023827
# 50%     17500.000000      0.054180
# 75%     32267.000000      0.099898
# max    323000.000000      1.000000

# %%
import joblib

# Serialize the scaler and maker_encoder objects
joblib.dump(scaler, 'scaler.joblib')
joblib.dump(maker_encoder, 'maker_encoder.joblib')

'''
Arriba guardo los objetos scaler y maker_encoder en archivos joblib para poder usarlos en el futuro, o ahorrar cache
'''

# Deserialize the scaler and maker_encoder objects
scaler = joblib.load('scaler.joblib')
maker_encoder = joblib.load('maker_encoder.joblib')

# Transform the dataset
train_scaled = train.copy()
train_scaled['mileage'] = scaler.transform(train[['mileage']])
train_scaled = train_scaled.join(pd.DataFrame(maker_encoder.transform(train[['brand', 'transmission', 'fuelType']]).toarray(), columns=maker_encoder.get_feature_names_out(['brand', 'transmission','fuelType'])))
train_scaled
# Out:
#            model    year    price transmission   mileage fuelType    tax  \
# 693      C Class  2018.0  27980.0    Semi-Auto  0.037687   Diesel    NaN
# 8809     Mokka X  2019.0  14450.0       Manual  0.023656   Petrol  145.0
# 233      M Class  2013.0  15990.0    Automatic  0.160372   Diesel  200.0
# 9408          Q2  2017.0  17995.0       Manual  0.052102   Petrol  145.0
# 7931    3 Series  2017.0  19499.0    Automatic  0.075765   Diesel   30.0
# ...          ...     ...      ...          ...       ...      ...    ...
# 910         Golf  2017.0  12700.0       Manual  0.070777   Petrol  150.0
# 1697       Focus  2017.0  10250.0       Manual  0.046285   Petrol    NaN
# 14623       Kuga  2016.0  13919.0       Manual  0.139319   Diesel  125.0
# 6208     C Class  2016.0  24890.0    Semi-Auto  0.077406   Diesel   30.0
# 6490    2 Series  2017.0  21995.0    Semi-Auto  0.068149   Petrol  200.0
#
#         mpg  engineSize     brand  ...  brand_vw  transmission_Automatic  \
# ...

# %%
import pickle

with open('scaler.pickle', 'wb') as wb:
    pickle.dump(scaler, wb)

with open('maker_encoder.pickle', 'wb') as wb:
    pickle.dump(maker_encoder, wb)

''' 
with open('scaler.pickle', 'rb') as rb:
    scaler = pickle.load(rb)
scaler.transform(train[['mileage']])
'''
# Out:
# " \nwith open('scaler.pickle', 'rb') as rb:\n    scaler = pickle.load(rb)\nscaler.transform(train[['mileage']])\n"

# %%
# Pipe lines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from sklearn.pipeline import FeatureUnion
from sklearn import set_config

# %%
# One-Hot Encoding maker, model, transmission, fuelType
one_hot_encoding = ColumnTransformer([
    (
        'one_hot_encoding', # Nombre de la transformación
        OneHotEncoder(),  # Transformador
        ['brand','transmission', 'fuelType'] # Columnas a transformar
    )
])

# %%
one_hot_encoding.fit(train)
# Out:
# ColumnTransformer(transformers=[('one_hot_encoding', OneHotEncoder(),
#                                  ['brand', 'transmission', 'fuelType'])])

# %%
#RobustScaler encoding mileage
robust_encoding = ColumnTransformer([
    (
        'robust_encoding', # Nombre de la transformación
        RobustScaler(),  # Transformador
        ['mileage'] # Columnas a transformar
    )
])

# %%
#Impute and standar scaler 
impute_and_scale = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

standar_scaling = ColumnTransformer([
    (
        'standar_scaling', # Nombre de la transformación
        impute_and_scale,  # Transformador
        ['mpg', 'tax'] # Columnas a transformar
    )
])

# %%
#Just pass year and engineSize sin transformar
pass_through = ColumnTransformer([
    (
        'pass_through', # Nombre de la transformación
        'passthrough',  # Transformador
        ['year', 'engineSize'] # Columnas a transformar
    )
])

# %%
#Ensambling the pipeleines

#Preprocessor va a ser un pipeline que va a tener un FeatureUnion que va a tener los pipelines de one_hot_encoding, robust_encoding, standar_scaling y pass_through
preprocessor = Pipeline([
    ('preprocessing', FeatureUnion([
        ('one_hot_encoding', one_hot_encoding),
        ('robust_encoding', robust_encoding),
        ('standar_scaling', standar_scaling),
        ('pass_through', pass_through)
    ]))
])

# %%
set_config(display='diagram')
preprocessor
# Out:
# Pipeline(steps=[('preprocessing',
#                  FeatureUnion(transformer_list=[('one_hot_encoding',
#                                                  ColumnTransformer(transformers=[('one_hot_encoding',
#                                                                                   OneHotEncoder(),
#                                                                                   ['brand',
#                                                                                    'transmission',
#                                                                                    'fuelType'])])),
#                                                 ('robust_encoding',
#                                                  ColumnTransformer(transformers=[('robust_encoding',
#                                                                                   RobustScaler(),
#                                                                                   ['mileage'])])),
# ...

# %%
train_preprocessed = preprocessor.fit_transform(train)
train_preprocessed = preprocessor.transform(train)
val_preprocessed = preprocessor.transform(val)
test_preprocessed = preprocessor.transform(test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
# Creando el pipe line que se va a encargar de hacer la predicción
predicting_pipe = Pipeline([
    ('feature_engineering', preprocessor),
    ('predictor', lr)
])

# %%
set_config(display='diagram')
predicting_pipe

'''
El pipeline predicting_pipe se encarga de hacer la predicción, primero pasa por el preprocesamiento de los datos y luego por el modelo de regresión lineal.
'''
# Out:
# '\nEl pipeline predicting_pipe se encarga de hacer la predicción, primero pasa por el preprocesamiento de los datos y luego por el modelo de regresión lineal.\n'

# %%
_ = predicting_pipe.fit(train, train['price'])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predicciones
train_preds = predicting_pipe.predict(train)
val_preds = predicting_pipe.predict(val)

# Cálculo de métricas
train_mse = mean_squared_error(train['price'], train_preds)
val_mse = mean_squared_error(val['price'], val_preds)

print(f"Train MSE: {train_mse}")
print(f"Validation MSE: {val_mse}")
# Out:
# Train MSE: 21775384.042679153
# Validation MSE: 23088731.614497542

# %%
import matplotlib.pyplot as plt


# Predicciones
train_preds = predicting_pipe.predict(train)
val_preds = predicting_pipe.predict(val)

# Gráfico de dispersión
plt.figure(figsize=(8, 8))
plt.scatter(train['price'], train_preds, alpha=0.5)
plt.scatter(val['price'], val_preds, alpha=0.5)
plt.xlabel('Valores reales')
plt.ylabel('Predicciones')
plt.title('Predicciones vs Valores reales')
plt.legend(['Entrenamiento', 'Validación'])
plt.show(block= True)

# %%
import seaborn as sns

# Dataframe con precios reales y predichos
df_preds = pd.DataFrame({
    'Real': np.concatenate([train['price'], val['price']]),
    'Predicho': np.concatenate([train_preds, val_preds]),
    'Conjunto': ['Entrenamiento']*len(train) + ['Validación']*len(val)
})

# Gráfico de caja
plt.figure(figsize=(12, 6))
sns.boxplot(x='Conjunto', y='Valor', hue='Tipo', data=df_preds.melt(id_vars='Conjunto', var_name='Tipo', value_name='Valor'))
plt.title('Distribución de los precios reales y predichos')
plt.show(block=True)
